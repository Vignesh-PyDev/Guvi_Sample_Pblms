# %% [markdown]
# # Create Matrix

# %%
import random
def Create_Matrix():
    print("\t\t\t\tCreating Martric with Given Rows and Column Values")
    Row_Size_m  = input("Enter Row_Size\t:")
    Column_Size_n  = input("Enter Column_Size\t:")
    if(Row_Size_m.isnumeric() and Column_Size_n.isnumeric()):
        print("You Need To Enter {} Values\t:".format(int(Column_Size_n) * int(Row_Size_m)))
        print("Press 1 fill Random Values to your Matrix:")
        print("Press 2 to fill Manual values(Time Consuming:)")
        Matrix_m_n =[ [x for x in range(int(Column_Size_n))] for k in range(int(Row_Size_m))]
        Matrix_Input_Data = input("Which One Do you Prefer:")
        if Matrix_Input_Data.isnumeric():
            if int(Matrix_Input_Data) == 1:
            
                for x in range(0, int(Row_Size_m)):
                    for y in range(0, int(Column_Size_n)):
                        Matrix_m_n[x][y]=(random.randrange(1, 9))
                return (Matrix_m_n)
            elif int(Matrix_Input_Data) == 2:
                
                for x in range(0, int(Row_Size_m)):
                    for y in range(0, int(Column_Size_n)):
                        Matrix_m_n[x][y]=(input("Enter Value For [{0}][{1}]\t".format(x,y)))
                return (Matrix_m_n)
            else:
                print("Invalid Choice!!!! choice")
                return Create_Matrix()
        else:
            print("Invalid Choice!!!!")
            return Create_Matrix()
    else:
        print("Enter Numeric Values:")
        return Create_Matrix()

# %%
Matrix_1,Matrix_2 = Create_Matrix(),Create_Matrix()

# %%
Matrix_1,Matrix_2

# %% [markdown]
# # Matrix Addition & Subraction
# Two matrices may be added or subtracted only if they have the same dimension; that is, they must have the same number of rows and columns.

# %% [markdown]
# ![Screenshot%20from%202021-03-03%2010-22-05.png](attachment:Screenshot%20from%202021-03-03%2010-22-05.png)

# %%
def Matrix_Dimension_Check(Mtrx1,Mtrx2):
    if(len(Mtrx1) == len(Mtrx2)):
        for x in range(len(Mtrx1)):
            if(len(Mtrx1[x]) == len(Mtrx2[x])):
                return 1
                break
            else:
                break
                return 0

# %%
def Matrix_Add(Mtrx_1,Mtrx_2):
    
    Result_Matrix_Add = []
    if(Matrix_Dimension_Check(Mtrx_1,Mtrx_2)):
        for x in range(len(Mtrx_1)):
            for y in range(len(Mtrx_1)):
                Result_Matrix_Add.append((Mtrx_1[x][y] + Mtrx_2[x][y]))
        return Result_Matrix_Add
    else:
        print("Matrtix Size Mismatch!!!\nCannot Perform Desired Operation")

# %%
def Matrix_Sub(Mtrx_1,Mtrx_2):
    
    Result_Matrix_Sub = []
    if(Matrix_Dimension_Check(Mtrx_1,Mtrx_2)):
        for x in range(len(Mtrx_1)):
            for y in range(len(Mtrx_1)):
                Result_Matrix_Sub.append((Mtrx_1[x][y] - Mtrx_2[x][y]))
        return Result_Matrix_Sub
    else:
        print("Matrtix Size Mismatch!!!\nCannot Perform Desired Operation")

# %%
Matrix_Sub(Matrix_1,Matrix_2)

# %%
Matrix_Add(Matrix_1,Matrix_2)

# %% [markdown]
# # Matrix Multipilcation

# %% [markdown]
# ![Screenshot%20from%202021-03-03%2019-23-31.png](attachment:Screenshot%20from%202021-03-03%2019-23-31.png)

# %% [markdown]
# ## Method 1 Using numpy

# %%
import numpy as np

# %%
np.dot(Matrix_1,Matrix_2)

# %% [markdown]
# ## Method 2 Using for loop

# %%
def Matrix_Product(Mtrx_1,Mtrx_2):
    if(len(Mtrx_1) == len(Mtrx_2)):       
        if(len(Mtrx_1[0]) > len(Mtrx_2[0])):
            Result_Matrix_Product_Size = [ [x for x in range(len(Mtrx_1[0]))] for k in range(len(Mtrx_1))]
        elif(len(Mtrx_1[0]) < len(Mtrx_2[0])):
            Result_Matrix_Product_Size = [ [x for x in range(len(Mtrx_2[0]))] for k in range(len(Mtrx_2))]
            
        else:
            Result_Matrix_Product_Size = [ [0 for x in range(len(Mtrx_2[0]))] for k in range(len(Mtrx_2))]
    
    for a in range(len(Mtrx_1)):
        for b in range(len(Mtrx_2[0])):
            for c in range(len(Y)):
                Result_Matrix_Product_Size[a][b] += Mtrx_1[a][c] * Mtrx_2[c][b]
    return Result_Matrix_Product_Size

# %%
Matrix_Product(Matrix_1,Matrix_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35ff7a633309> in <module>
# ----> 1 Matrix_Product(Matrix_1,Matrix_2)
#
# NameError: name 'Matrix_1' is not defined
